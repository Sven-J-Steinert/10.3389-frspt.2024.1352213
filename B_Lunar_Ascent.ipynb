# %% [markdown]
# # <font style="color: rgb(0,0,0);">Framework Implemention of this paper</font> <font style="color: rgb(190,138,67);">10.1016/j.advengsoft.2016.01.002</font>
#
# A unified trajectory optimization framework for lunar ascent<br>
# Lin Ma a,1, Weifeng Chen b,2, Zhengyu Song c,3,∗, Zhijiang Shao<br>
# http://dx.doi.org/10.1016/j.advengsoft.2016.01.002

# %%
# imports
import numpy as np

# constants
r_moon = 1737400    # [m] volumetric mean radius of the moon = reference height from heightmap
m_moon = 0.07346e24 # [kg] mass of the moon
G = 6.67430e-11 # Gravitational constant

# %% [markdown]
# Taskflow
#
# ![image.png](attachment:3ea24442-a8b2-4eb6-a634-406e65473c20.png)

# %% [markdown]
# Coordinate system (Fig. 2)
#
# ![image.png](attachment:95c399f4-2501-41b5-8f8e-b97565479608.png)

# %%
# define variables
X, Y, Z = 0,0,0
XYZ = np.array([X,Y,Z])
r = np.array([0,0,0])
